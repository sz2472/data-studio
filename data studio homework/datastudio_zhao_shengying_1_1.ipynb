# %%
import pandas as pd
import matplotlib.pyplot as plt #matplotlib.pyplot is a collection of command style functions that make matplotlib work like MATLAB. Each pyplot function makes some change to a figure
import numpy as np #numpy arrays
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
# %matplotlib inline

# %%
performance_df = pd.read_excel("../01-classwork/NBA stats.xlsx", sheetname="Player performance")

# %%
performance_df.head(5)
# Out:
#              Player                   TEAM  AGE  GP   W   L   MIN   FGM   FGA  \
# 0     Stephen Curry  Golden State Warriors   28  79  71   8  34.2  10.2  20.2
# 1      James Harden        Houston Rockets   26  82  41  41  38.1   8.7  19.7
# 2      Kevin Durant  Oklahoma City Thunder   27  72  52  20  35.8   9.7  19.2
# 3  DeMarcus Cousins       Sacramento Kings   25  65  29  36  34.6   9.2  20.5
# 4      LeBron James    Cleveland Cavaliers   31  76  56  20  35.6   9.7  18.6
#
#     FG%  ...   DREB   REB  AST  TOV  STL  BLK   PF  DD2  TD3   PTS
# 0  50.4  ...    4.6   5.4  6.7  3.3  2.1  0.2  2.0   15    2  30.1
# 1  43.9  ...    5.3   6.1  7.5  4.6  1.7  0.6  2.8   23    3  29.0
# 2  50.5  ...    7.6   8.2  5.0  3.5  1.0  1.2  1.9   27    1  28.2
# 3  45.1  ...    9.1  11.5  3.3  3.8  1.6  1.4  3.6   47    1  26.9
# 4  52.0  ...    6.0   7.4  6.8  3.3  1.4  0.6  1.9   28    3  25.3
#
# [5 rows x 27 columns]

# %%
salary_df = pd.read_excel("../01-classwork/NBA stats.xlsx", sheetname="2016-2017 Salaries")
salary_df.head(5)
# Out:
#    RK             NAME POS                    TEAM    SALARY
# 0   1      Mike Conley  PG       Memphis Grizzlies  26540100
# 1   2       Al Horford   C          Boston Celtics  26540100
# 2   3  Carmelo Anthony  SF         New York Knicks  24559380
# 3   4   Damian Lillard  PG  Portland Trail Blazers  24328425
# 4   5       Chris Bosh  PF              Miami Heat  23741060

# %%
df = performance_df.merge(salary_df, left_on='Player', right_on='NAME')
df.head()
# Out:
#               Player                  TEAM_x  AGE  GP   W   L   MIN   FGM  \
# 0      Stephen Curry   Golden State Warriors   28  79  71   8  34.2  10.2
# 1   DeMarcus Cousins        Sacramento Kings   25  65  29  36  34.6   9.2
# 2     Damian Lillard  Portland Trail Blazers   25  75  40  35  35.7   8.2
# 3      Anthony Davis    New Orleans Pelicans   23  61  24  37  35.5   9.2
# 4  Russell Westbrook   Oklahoma City Thunder   27  80  55  25  34.4   8.2
#
#     FGA   FG%    ...     BLK   PF  DD2  TD3   PTS  RK               NAME  POS  \
# 0  20.2  50.4    ...     0.2  2.0   15    2  30.1  68      Stephen Curry   PG
# 1  20.5  45.1    ...     1.4  3.6   47    1  26.9  35   DeMarcus Cousins    C
# 2  19.7  41.9    ...     0.4  2.2   15    0  25.1   4     Damian Lillard   PG
# 3  18.6  49.3    ...     2.0  2.4   36    0  24.3  11      Anthony Davis   PF
# 4  18.1  45.4    ...     0.3  2.5   54   18  23.5  24  Russell Westbrook   PG
#
#                    TEAM_y    SALARY
# ...

# %% [markdown]
# Using the NBA data, make a chart that highlights two specific players that make either a lot or a little money vs. how well they perform. Add their names and a little information about them to the chart. Play around with fonts and colors, make that chart look great!

# %%
df.columns
# Out:
# Index(['Player', 'TEAM_x',    'AGE',     'GP',      'W',      'L',    'MIN',
#           'FGM',    'FGA',    'FG%', 15:00:00,    '3PA',    '3P%',    'FTM',
#           'FTA',    'FT%',   'OREB',   'DREB',    'REB',    'AST',    'TOV',
#           'STL',    'BLK',     'PF',    'DD2',    'TD3',    'PTS',     'RK',
#          'NAME',    'POS', 'TEAM_y', 'SALARY'],
#       dtype='object')

# %%
df.sort_values(by="PTS",ascending=False)
# Out:
#                  Player                  TEAM_x  AGE  GP   W   L   MIN   FGM  \
# 0         Stephen Curry   Golden State Warriors   28  79  71   8  34.2  10.2
# 1      DeMarcus Cousins        Sacramento Kings   25  65  29  36  34.6   9.2
# 2        Damian Lillard  Portland Trail Blazers   25  75  40  35  35.7   8.2
# 3         Anthony Davis    New Orleans Pelicans   23  61  24  37  35.5   9.2
# 4     Russell Westbrook   Oklahoma City Thunder   27  80  55  25  34.4   8.2
# 5           Paul George          Indiana Pacers   26  81  44  37  34.8   7.5
# 6         Isaiah Thomas          Boston Celtics   27  82  48  34  32.2   7.2
# 7         Klay Thompson   Golden State Warriors   26  80  71   9  33.3   8.1
# 8       Carmelo Anthony         New York Knicks   32  72  32  40  35.1   7.9
# 9         Blake Griffin    Los Angeles Clippers   27  35  22  13  33.4   8.6
# 10        Kawhi Leonard       San Antonio Spurs   25  72  60  12  33.1   7.7
# ...

# %%
df.sort_values(by="SALARY",ascending=False)
# Out:
#                 Player                  TEAM_x  AGE  GP   W   L   MIN  FGM  \
# 45         Mike Conley       Memphis Grizzlies   28  56  33  23  31.4  5.3
# 47          Al Horford           Atlanta Hawks   30  82  48  34  32.1  6.5
# 8      Carmelo Anthony         New York Knicks   32  72  32  40  35.1  7.9
# 2       Damian Lillard  Portland Trail Blazers   25  75  40  35  35.7  8.2
# 22          Chris Bosh              Miami Heat   32  53  29  24  33.5  6.8
# 23         Dwyane Wade              Miami Heat   34  74  43  31  30.5  7.3
# 70       Dwight Howard         Houston Rockets   30  71  34  37  32.1  5.2
# 21          Chris Paul    Los Angeles Clippers   31  74  50  24  32.7  7.0
# 59    Hassan Whiteside              Miami Heat   27  73  42  31  29.1  5.7
# 69    Chandler Parsons        Dallas Mavericks   27  61  29  32  29.5  5.2
# 3        Anthony Davis    New Orleans Pelicans   23  61  24  37  35.5  9.2
# ...

# %%
#the player scores best at PTS but makes relatively less money
player1=df[df['Player']=='Stephen Curry']
player1
# Out:
#           Player                 TEAM_x  AGE  GP   W  L   MIN   FGM   FGA  \
# 0  Stephen Curry  Golden State Warriors   28  79  71  8  34.2  10.2  20.2
#
#     FG%    ...     BLK   PF  DD2  TD3   PTS  RK           NAME  POS  \
# 0  50.4    ...     0.2  2.0   15    2  30.1  68  Stephen Curry   PG
#
#                   TEAM_y    SALARY
# 0  Golden State Warriors  12112359
#
# [1 rows x 32 columns]

# %%
#the player makes the most among others yet scores in the middle in terms of PTS
player2=df[df['Player']=='Mike Conley']
player2
# Out:
#          Player             TEAM_x  AGE  GP   W   L   MIN  FGM   FGA   FG%  \
# 45  Mike Conley  Memphis Grizzlies   28  56  33  23  31.4  5.3  12.4  42.2
#
#       ...     BLK   PF  DD2  TD3   PTS  RK         NAME  POS  \
# 45    ...     0.3  1.8    4    0  15.3   1  Mike Conley   PG
#
#                TEAM_y    SALARY
# 45  Memphis Grizzlies  26540100
#
# [1 rows x 32 columns]

# %% [markdown]
# PART TWO
#
# Using the NBA data, make a chart that highlights two specific players that make either a lot or a little money vs. how well they perform. Add their names and a little information about them to the chart. Play around with fonts and colors, make that chart look great!

# %%
ax = df.plot(kind='scatter', y='SALARY', x='PTS', marker='o', figsize=(10, 5))
player1.plot(kind="scatter", y='SALARY', x='PTS', ax=ax, label='Stephen Curry', color='red')
player2.plot(kind="scatter", y='SALARY', x='PTS', ax=ax, label='Mike Conley', color='yellow')
ax.set_ylabel("SALARY")
ax.set_xlabel("POINTS")
ax.set_xlim([0, 35])
ax.set_ylim([0, 30000000])
plt.savefig("nba-interesting-players.pdf",transparent=True)

# %% [markdown]
# PART THREE
#
# Using the scrabble data, reproduce the "Nigel Richards's Performance at Nationals" chart from FiveThirtyEight (minus the UFO bits). Build the basic chart from this dataframe:
#
# points_df  = pd.read_csv("scrabble-point-spread.csv")
# tournament_df = pd.read_csv("scrabble-tournament.csv")
# df = tournament_df.merge(points_df, left_on='Player ID', right_on='player_id').fillna(0)
# df.head()
#
# Hot tip: You might want to start with matplotlib using the fivethirtyeight style. Check this blog post for info on how to make arrows.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import matplotlib

# %%
point_df  = pd.read_csv("scrabble-point-spread.csv")
tournament_df = pd.read_csv("scrabble-tournament.csv")

# %%
point_df.head()
# Out:
#    player_id  points_against  points_for  tournament_id
# 0       6003             381         443           8163
# 1      20749             375         435           8163
# 2      19535             391         443           8163
# 3      18474             386         439           8163
# 4        583             396         450           8163

# %%
tournament_df.head()
# Out:
#    Byes  Credits  Losses                   Name  New Rating  Old Rating  \
# 0   NaN      NaN       7         Nigel Richards        2196      2168.0
# 1   NaN      NaN       7  Komol Panyasophonlert        2070      2002.0
# 2   NaN      NaN       8          Will Anderson        2093      2054.0
# 3   NaN      NaN       9            Noah Walton        2063      2015.0
# 4   NaN      NaN      10        Kenji Matsumoto        2057      2023.0
#
#   Other Money  Perf Rating  Place  Player ID Prize Money  Seed  Spread  Ties  \
# 0         NaN       2356.0      1       6003     $10,000     1    1934   NaN
# 1         NaN       2372.0      2      20749      $3,000    11    1868   NaN
# 2         NaN       2264.0      3      19535      $2,000     2    1623   NaN
# 3         NaN       2239.0      4      18474      $1,000     8    1628   NaN
# 4         NaN       2212.0      5        583        $800     5    1671   NaN
#
#    Tournament ID  Wins    division
# ...

# %%
df = tournament_df.merge(point_df, left_on='Player ID', right_on='player_id').fillna(0)

# %%
df.head()
# Out:
#    Byes  Credits  Losses                   Name  New Rating  Old Rating  \
# 0   0.0      0.0       7         Nigel Richards        2196      2168.0
# 1   0.0      0.0       7  Komol Panyasophonlert        2070      2002.0
# 2   0.0      0.0       8          Will Anderson        2093      2054.0
# 3   0.0      0.0       9            Noah Walton        2063      2015.0
# 4   0.0      0.0      10        Kenji Matsumoto        2057      2023.0
#
#   Other Money  Perf Rating  Place  Player ID      ...       Seed  Spread  \
# 0           0       2356.0      1       6003      ...          1    1934
# 1           0       2372.0      2      20749      ...         11    1868
# 2           0       2264.0      3      19535      ...          2    1623
# 3           0       2239.0      4      18474      ...          8    1628
# 4           0       2212.0      5        583      ...          5    1671
#
#    Ties  Tournament ID  Wins    division player_id  points_against  \
# ...

# %%
df_1 = df[df["division"]=="Division 1"]
df_2 = df[df["division"]=="Division 2"]
df_3 = df[df["division"]=="Division 3"]
df_4 = df[df["division"]=="Division 4"]

# %%
fig, ax = plt.subplots(figsize=(10,5))
for category, group in df.groupby('division'):
    ax.plot(group['points_for'],group['points_against'], marker='o', linestyle='', label=category, markeredgewidth=0)
    ax.set_xlim([300,460])
    ax.set_ylim([300,460])
    ax.legend()
plt.savefig("scrabble.pdf",transparent=True)

# %%
for category, group in df.groupby('division'):#category is the name of the groupby item, group is the dataframe
    print(category)
    print(group)
# Out:
# Division 1
#      Byes  Credits  Losses                     Name  New Rating  Old Rating  \
# 0     0.0      0.0       7           Nigel Richards        2196      2168.0
# 1     0.0      0.0       7    Komol Panyasophonlert        2070      2002.0
# 2     0.0      0.0       8            Will Anderson        2093      2054.0
# 3     0.0      0.0       9              Noah Walton        2063      2015.0
# 4     0.0      0.0      10          Kenji Matsumoto        2057      2023.0
# 5     0.0      0.0      10              Scott Appel        2001      1920.0
# 6     0.0      0.0      10              Mack Meller        2035      2014.0
# 7     0.0      0.0      11               Rafi Stern        2033      2030.0
# 8     0.0      0.0      11                Jesse Day        2022      2021.0
# 9     0.0      0.0      12             Dave Wiegand        2016      2000.0
# 10    0.0      0.0      12               Trip Payne        1883      1818.0
# ...

# %%
fig, ax = plt.subplots(figsize=(10,5))
for category, group in df.groupby('division'):
    ax.plot(group['points_for'],group['points_against'], marker='o', linestyle='', label=category, markeredgewidth=0)
    ax.set_xlim([300,460])
    ax.set_ylim([300,460])
    ax.legend()
plt.savefig("scrabble.pdf",transparent=True)
